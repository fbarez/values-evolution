# %% [markdown]
# # Data Audit
#
# Per-wave distributions, missingness, and mode effects.
#
# **Run after**: `scripts/fetch_data.py` + `scripts/build_corpus.py`

# %%
# TODO: implement
# 1. Load data/interim/ parquet files
# 2. Per-wave: n respondents, n countries, missingness heatmap
# 3. Per-construct: distribution shifts across waves
# 4. Mode effects: CAPI vs CAWI response distributions
# 5. Flag items with >30% missing in any wave
