# %% [markdown]
# # Baseline Analysis
#
# Cohort-replacement and persistence baselines on the validation set.
#
# **Run after**: `scripts/run_eval.py` with base checkpoint.

# %%
# TODO: implement
# 1. Load outputs/evals/baseline/results.json
# 2. Compute persistence and cohort_replacement baselines
# 3. Plot: baseline JS vs. construct, baseline JS vs. country
# 4. Identify constructs where baselines are hardest to beat (high stability)
# 5. Identify countries with high value volatility (baselines fail there too)
